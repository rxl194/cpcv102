# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE
# Out:
# /home/ystd2016/anaconda2/envs/tensorflow/lib/python2.7/site-packages/matplotlib/font_manager.py:280: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'anarchism', 'term', 'a', 'originated', 'of', 'term', 'as']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.173914
# Nearest to at: sorties, redefining, disrespectful, inc, carries, intercontinental, fairmount, bahia,
# Nearest to been: gnosis, holyhead, neva, concentric, statesman, riigikogu, positives, krajina,
# Nearest to and: hydrodynamic, honoring, valdes, huckleberry, lakeshore, seaboard, chase, macpherson,
# Nearest to d: ic, exposition, undulating, unsubstantiated, ayckbourn, milner, metalwork, misused,
# Nearest to also: eurotunnel, adair, twos, coexisted, misty, endless, elemental, centaurus,
# Nearest to who: lunda, alleviation, mycobacterium, kildall, petr, krush, horrific, deconstruction,
# Nearest to no: navies, legendre, tempering, nasr, arrangement, lesser, screened, agile,
# Nearest to is: white, secede, paco, laminated, leyden, moabites, lukoff, jeffrey,
# Nearest to a: deferred, gry, hellas, endemic, neoconservative, whoever, raccoons, suitably,
# Nearest to american: mpr, irreducibly, webcam, postponed, fyrom, fiction, chs, deposing,
# Nearest to may: freer, freedoms, haarlem, travel, parenthood, labouring, anjou, martialed,
# Nearest to have: canonized, sega, tf, reginae, paedophilia, hutchence, computers, fascism,
# Nearest to world: dhekelia, kissing, tablet, aero, ruined, tiberius, carangi, virulence,
# Nearest to not: tiki, hatching, theme, rigour, dreadnoughts, et, reconsider, subsection,
# Nearest to has: voris, vicinity, broadcasters, behaviorism, declines, europa, skeleton, petrovi,
# Nearest to years: brood, runoff, tegucigalpa, thetis, cours, irv, frankie, not,
# Average loss at step 2000: 4.377475
# Average loss at step 4000: 3.875472
# Average loss at step 6000: 3.796579
# Average loss at step 8000: 3.758871
# Average loss at step 10000: 3.620562
# Nearest to at: in, by, fei, carries, on, from, with, roost,
# Nearest to been: tyndale, was, aztlan, holyhead, jolly, krajina, quite, staunch,
# Nearest to and: or, pauline, for, on, in, with, charisma, from,
# Nearest to d: ic, b, metalwork, branches, khoikhoi, exposition, introductions, undulating,
# Nearest to also: now, twos, who, elemental, which, alamo, it, simply,
# Nearest to who: he, mycobacterium, also, alleviation, horrific, yudhoyono, tnf, haines,
# Nearest to no: arrangement, lax, navies, considerable, nasr, tempering, a, it,
# Nearest to is: was, are, has, were, rolfe, does, centimetre, be,
# Nearest to a: the, this, samuelson, deferred, frets, flowered, no, tubing,
# Nearest to american: webcam, marinetti, mpr, capcom, historic, appia, danish, chs,
# Nearest to may: would, can, winnipeg, hrvatska, labouring, compute, haig, you,
# Nearest to have: has, had, are, be, were, hutchence, clarinet, tarski,
# Nearest to world: notational, carangi, dhekelia, dns, ruined, legged, retrospectively, colombians,
# Nearest to not: rigour, it, tiki, itself, never, kluwer, examples, gradually,
# Nearest to has: have, is, had, was, through, streamlining, alabaster, refute,
# Nearest to years: brood, krill, coincidentally, fisa, six, gc, inanna, transgendered,
# Average loss at step 12000: 3.583127
# Average loss at step 14000: 3.608006
# Average loss at step 16000: 3.586873
# Average loss at step 18000: 3.572863
# Average loss at step 20000: 3.546523
# Nearest to at: in, from, carries, within, roost, on, barada, same,
# Nearest to been: tyndale, be, was, aztlan, by, become, had, quite,
# Nearest to and: or, s, but, with, who, in, of, amillennialism,
# Nearest to d: b, khoikhoi, ic, stallions, metalwork, bute, undulating, introductions,
# Nearest to also: now, who, often, which, arsenic, it, alamanni, generally,
# Nearest to who: he, also, there, they, and, which, dated, tnf,
# Nearest to no: likely, byrnes, navies, considerable, lax, arrangement, investigated, labeled,
# Nearest to is: was, has, are, does, forcing, rolfe, became, were,
# Nearest to a: greta, the, pronouncements, this, its, peninsulas, theophilus, no,
# Nearest to american: marinetti, english, cosmogony, italian, webcam, british, fiction, buys,
# Nearest to may: can, would, will, should, must, might, could, hrvatska,
# Nearest to have: had, has, be, are, were, do, catered, contributed,
# Nearest to world: carangi, notational, legged, aero, mints, ruined, esas, virulence,
# Nearest to not: never, often, theme, usually, also, always, tiki, ghamdi,
# Nearest to has: had, have, was, is, streamlining, bicoid, skeleton, through,
# Nearest to years: brood, deck, krill, coincidentally, inanna, docetism, qi, gc,
# Average loss at step 22000: 3.529293
# Average loss at step 24000: 3.440598
# Average loss at step 26000: 3.413621
# Average loss at step 28000: 3.475160
# Average loss at step 30000: 3.406491
# Nearest to at: in, on, from, intercontinental, within, kazimierz, graced, through,
# Nearest to been: be, become, tyndale, were, aztlan, already, had, was,
# Nearest to and: or, but, farmed, who, s, with, ridinghood, easterly,
# Nearest to d: b, metalwork, oireachtas, worker, ic, bute, bodleian, saigon,
# Nearest to also: now, often, which, generally, then, never, quickly, not,
# Nearest to who: he, which, they, never, she, and, also, ska,
# Nearest to no: byrnes, likely, labeled, consumed, reynard, disagreement, beau, prepared,
# Nearest to is: was, has, are, be, does, jokingly, if, became,
# Nearest to a: another, peninsulas, the, pandit, superset, constricted, looting, greta,
# Nearest to american: british, italian, german, french, english, danish, b, mpr,
# Nearest to may: can, would, will, could, should, might, must, cannot,
# Nearest to have: had, has, be, were, are, include, glorification, tend,
# Nearest to world: carangi, notational, mints, civil, sofa, scrambling, legged, heh,
# Nearest to not: they, it, never, we, also, always, actually, you,
# Nearest to has: had, have, is, was, streamlining, skeleton, kantele, refute,
# Nearest to years: days, brood, docetism, members, inanna, deck, qi, developers,
# Average loss at step 32000: 3.413391
# Average loss at step 34000: 3.434673
# Average loss at step 36000: 3.361422
# Average loss at step 38000: 3.494326
# Average loss at step 40000: 3.441647
# Nearest to at: in, melissa, barada, during, on, within, arbitrary, once,
# Nearest to been: become, be, was, tyndale, were, aztlan, shehri, had,
# Nearest to and: or, but, than, ridinghood, which, transitioning, relinquished, though,
# Nearest to d: b, khoikhoi, r, bute, blizzards, neglect, reith, h,
# Nearest to also: which, now, often, quickly, never, generally, who, simply,
# Nearest to who: he, they, which, never, she, also, icing, flashlight,
# Nearest to no: likely, consumed, grbac, considerable, labeled, lax, a, retreats,
# Nearest to is: was, are, has, be, does, contains, if, rolfe,
# Nearest to a: the, greta, any, another, samuelson, relatively, waterway, chanced,
# Nearest to american: italian, british, ystem, french, gollancz, german, danish, cosmogony,
# Nearest to may: can, would, will, could, must, should, might, cannot,
# Nearest to have: had, has, are, include, be, were, glorification, receive,
# Nearest to world: carangi, unicode, series, legged, civil, mints, ros, sofa,
# Nearest to not: they, never, ghamdi, reconsider, usually, fulltext, thistle, you,
# Nearest to has: had, have, was, is, caesars, jokingly, streamlining, refute,
# Nearest to years: days, year, times, docetism, deck, brood, decades, catalysis,
# Average loss at step 42000: 3.425020
# Average loss at step 44000: 3.276909
# Average loss at step 46000: 3.409509
# Average loss at step 48000: 3.428628
# Average loss at step 50000: 3.436090
# Nearest to at: in, on, melissa, during, barada, near, under, arbitrary,
# Nearest to been: become, be, already, tyndale, had, never, shehri, was,
# Nearest to and: but, or, like, when, however, which, pg, araki,
# Nearest to d: b, khoikhoi, r, reith, n, borghese, eval, stallions,
# Nearest to also: often, now, generally, sometimes, never, which, quickly, alamo,
# Nearest to who: he, never, she, which, also, ska, porpoise, they,
# Nearest to no: any, a, only, another, vivian, labeled, meadows, likely,
# Nearest to is: was, has, became, lawmaking, are, be, were, although,
# Nearest to a: another, the, greta, any, no, samuelson, expectancy, dishes,
# Nearest to american: italian, british, african, german, ystem, french, gollancz, danish,
# Nearest to may: can, would, will, could, must, might, should, cannot,
# Nearest to have: had, has, were, be, include, glorification, freer, hitachi,
# Nearest to world: carangi, legged, heh, unicode, ros, vorkosigan, civil, esas,
# Nearest to not: never, usually, tachi, ghamdi, they, rigour, often, reconsider,
# Nearest to has: had, have, was, is, kantele, caesars, jokingly, since,
# Nearest to years: days, times, decades, year, deck, catalysis, brood, docetism,
# Average loss at step 52000: 3.452877
# Average loss at step 54000: 3.433039
# Average loss at step 56000: 3.405667
# Average loss at step 58000: 3.279737
# Average loss at step 60000: 3.381628
# Nearest to at: in, during, alain, university, barada, on, after, from,
# Nearest to been: become, be, was, were, tyndale, deviate, already, aztlan,
# Nearest to and: or, but, who, which, including, charisma, nominees, transitioning,
# Nearest to d: b, khoikhoi, stallions, n, r, l, borghese, o,
# Nearest to also: often, never, now, which, who, generally, still, sometimes,
# Nearest to who: which, also, he, and, she, never, icing, there,
# Nearest to no: any, lexical, only, another, it, vivian, considerable, ramp,
# Nearest to is: was, has, are, does, became, if, be, although,
# Nearest to a: another, the, samuelson, greta, peninsulas, any, no, reactor,
# Nearest to american: italian, british, african, german, english, french, ystem, australian,
# Nearest to may: can, would, could, will, must, should, might, cannot,
# Nearest to have: had, has, were, include, are, be, freer, tend,
# Nearest to world: carangi, heh, civil, scrambling, peep, unicode, ros, southerly,
# Nearest to not: never, they, really, rigour, thistle, consent, reconsider, boomed,
# Nearest to has: had, have, is, was, kantele, caesars, although, underwater,
# Nearest to years: days, decades, times, months, year, weeks, minutes, deck,
# Average loss at step 62000: 3.438445
# Average loss at step 64000: 3.358710
# Average loss at step 66000: 3.345349
# Average loss at step 68000: 3.384224
# Average loss at step 70000: 3.369445
# Nearest to at: in, on, during, near, around, kazimierz, alain, within,
# Nearest to been: become, be, already, deviate, were, tyndale, was, since,
# Nearest to and: or, but, see, while, pauline, although, caf, charisma,
# Nearest to d: b, khoikhoi, matheson, reith, stallions, borghese, winged, blizzards,
# Nearest to also: now, never, often, still, which, eventually, usually, generally,
# Nearest to who: he, they, still, she, never, also, which, ska,
# Nearest to no: any, another, sheds, grbac, ponty, lexical, realizing, considerable,
# Nearest to is: was, are, has, possesses, became, does, although, includes,
# Nearest to a: another, greta, the, tarnished, any, waterway, homesick, medusa,
# Nearest to american: italian, british, french, german, african, australian, gollancz, yuri,
# Nearest to may: can, would, could, will, must, should, might, cannot,
# Nearest to have: had, has, were, include, be, are, having, freer,
# Nearest to world: carangi, ranging, heh, civil, cold, ros, blinding, weidenfeld,
# Nearest to not: never, they, still, also, now, really, milken, rigour,
# Nearest to has: had, have, was, is, caesars, underwater, generously, although,
# Nearest to years: days, decades, year, months, times, weeks, miles, minutes,
# Average loss at step 72000: 3.403167
# Average loss at step 74000: 3.389529
# Average loss at step 76000: 3.347097
# Average loss at step 78000: 3.235712
# Average loss at step 80000: 3.372054
# Nearest to at: during, near, on, fei, aedui, thespis, temperature, in,
# Nearest to been: become, be, already, were, deviate, was, tyndale, begun,
# Nearest to and: or, but, while, of, however, boitano, including, alma,
# Nearest to d: b, khoikhoi, l, vives, matheson, winged, c, reith,
# Nearest to also: often, now, still, which, never, sometimes, generally, formally,
# Nearest to who: he, never, they, often, still, she, which, also,
# Nearest to no: any, another, sheds, adjustments, there, realizing, bodies, lexical,
# Nearest to is: was, has, are, be, became, does, if, makes,
# Nearest to a: another, the, any, waterway, tougher, expectancy, nemo, greta,
# Nearest to american: italian, british, african, german, australian, gollancz, french, irish,
# Nearest to may: can, would, could, will, must, should, might, cannot,
# Nearest to have: had, has, were, are, include, perform, having, freer,
# Nearest to world: carangi, heh, ros, civil, peep, ranging, southerly, historically,
# Nearest to not: never, still, tumultuous, mold, sanj, actually, unlikely, rigour,
# Nearest to has: had, have, is, was, underwater, since, although, frivolous,
# Nearest to years: days, year, decades, months, weeks, times, deck, minutes,
# Average loss at step 82000: 3.295796
# Average loss at step 84000: 3.340448
# Average loss at step 86000: 3.348406
# Average loss at step 88000: 3.321137
# Average loss at step 90000: 3.241970
# Nearest to at: during, in, melissa, on, near, compaor, after, kazimierz,
# Nearest to been: become, be, was, already, begun, deviate, tyndale, were,
# Nearest to and: or, american, including, but, decoded, spokesman, b, who,
# Nearest to d: b, uss, l, khoikhoi, matheson, c, undisturbed, pseudocode,
# Nearest to also: never, now, which, often, still, eventually, sometimes, who,
# Nearest to who: which, never, still, often, he, also, now, she,
# Nearest to no: any, lexical, sheds, delft, argumentation, grbac, bodies, little,
# Nearest to is: was, became, are, although, were, vec, possesses, be,
# Nearest to a: another, the, peninsulas, relatively, greta, cremona, rumour, bonded,
# Nearest to american: italian, and, british, german, australian, ystem, french, african,
# Nearest to may: can, could, must, will, would, might, should, cannot,
# Nearest to have: had, has, include, be, are, were, having, perform,
# Nearest to world: heh, carangi, civil, southerly, ros, higgs, ranging, cold,
# Nearest to not: never, unlikely, really, you, sanj, now, ghamdi, still,
# Nearest to has: had, have, was, bicoid, underwater, is, although, wrote,
# Nearest to years: days, months, decades, year, weeks, times, minutes, centuries,
# Average loss at step 92000: 2.735760
# Average loss at step 94000: 3.098390
# Average loss at step 96000: 3.067977
# Average loss at step 98000: 3.221302
# Average loss at step 100000: 3.277425
# Nearest to at: during, near, in, on, around, kinematic, despite, cycling,
# Nearest to been: become, be, already, begun, was, were, deviate, overflowing,
# Nearest to and: but, or, however, while, which, though, including, nutritious,
# Nearest to d: b, matheson, ziibi, comforted, pillow, worker, strut, interpolating,
# Nearest to also: never, now, often, still, eventually, sometimes, which, generally,
# Nearest to who: still, which, often, also, he, that, never, ska,
# Nearest to no: any, lexical, little, bodies, sucre, than, delft, another,
# Nearest to is: was, has, although, does, are, requires, possesses, contains,
# Nearest to a: the, another, any, greta, this, every, tarnished, homesick,
# Nearest to american: british, english, african, italian, australian, irish, canadian, indian,
# Nearest to may: can, must, could, would, will, should, might, cannot,
# Nearest to have: had, has, include, were, having, are, perform, be,
# Nearest to world: carangi, heh, southerly, legged, ros, fretting, ranging, arcade,
# Nearest to not: never, now, unlikely, nor, really, sanj, also, still,
# Nearest to has: had, have, is, was, underwater, although, having, bicoid,
# Nearest to years: days, year, months, decades, weeks, minutes, humpback, centuries,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        # WOW SUCH CBOW
        batch_labels, batch_data = generate_batch(batch_size, num_skips, skip_window)
        batch_data = batch_data.reshape((batch_size,))
        batch_labels = batch_labels.reshape((batch_size, 1))
        
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.622589
# Nearest to at: depeche, albans, godard, parentage, whammy, assoc, yahoo, confluence,
# Nearest to been: rinzai, crusoe, turnpike, walked, warcraft, drusus, entomology, vlsi,
# Nearest to and: hume, bechtel, blunder, ustinov, cirencester, microeconomics, christian, eyes,
# Nearest to d: heritable, plentiful, disparities, mattingly, polymyositis, callimachus, camcorders, ukiyo,
# Nearest to also: blizzards, crept, ilium, johnnie, mithraea, republicans, nico, prerogative,
# Nearest to who: kaye, woolly, monochromatic, rede, anders, claimed, feasibility, malfunction,
# Nearest to no: comets, convenience, bestseller, arranger, disoriented, alvin, plunging, curfew,
# Nearest to is: widowers, hara, na, byelorussia, dissenters, splits, emigrant, norden,
# Nearest to a: christophe, bamboo, galleon, disease, oxymoron, mastermind, suggests, piercer,
# Nearest to american: lanthanum, wehrmacht, abandons, stature, appropriately, christened, incorruptible, compost,
# Nearest to may: constitutionally, bereshit, relates, azathoth, coral, triadic, ratify, mullin,
# Nearest to have: mcclure, polynomial, touched, regulars, watchmen, firstly, demarcation, eloquent,
# Nearest to world: ruthenia, kidnap, uppermost, dorothea, concerti, selznick, leftrightarrow, infested,
# Nearest to not: collectivism, theme, heighten, admixtures, unloading, supranationalism, pore, gos,
# Nearest to has: theophoric, fiend, insensitivity, essences, gauges, interdisciplinarity, pascal, greatest,
# Nearest to years: notes, gq, danville, purview, tariffs, carthaginian, ux, lansing,
# Average loss at step 2000: 4.296573
# Average loss at step 4000: 3.850147
# Average loss at step 6000: 3.754968
# Average loss at step 8000: 3.727064
# Average loss at step 10000: 3.668151
# Nearest to at: in, depeche, on, godard, cyclopaedia, boleslav, for, during,
# Nearest to been: was, turnpike, never, burgess, jati, be, forward, also,
# Nearest to and: or, with, in, aerospace, from, australian, weidman, by,
# Nearest to d: heritable, plentiful, mattingly, polymyositis, disparities, callimachus, gerry, dismantle,
# Nearest to also: it, who, still, which, often, not, cooperates, kazakhstan,
# Nearest to who: woolly, he, harpist, which, also, anders, quadrants, kaye,
# Nearest to no: mazes, tags, nan, modestly, along, alvin, recreating, buyer,
# Nearest to is: was, has, are, became, be, were, as, burgess,
# Nearest to a: the, ayub, piercer, unmodified, oxymoron, genosha, vita, more,
# Nearest to american: lanthanum, papa, fellowships, wehrmacht, anacletus, ili, philanthropist, scratched,
# Nearest to may: would, can, fraternities, constitutionally, could, lose, bereshit, should,
# Nearest to have: had, has, be, are, matthews, were, watchmen, ask,
# Nearest to world: dorothea, kidnap, devo, uppermost, ruthenia, realaudio, kumquats, riverboat,
# Nearest to not: still, assignments, also, it, they, arose, naturalistic, heighten,
# Nearest to has: had, is, was, have, idol, elevation, hyperlinks, kaposi,
# Nearest to years: notes, organiser, lansing, kyiv, staging, mousse, incensed, cheek,
# Average loss at step 12000: 3.675073
# Average loss at step 14000: 3.530341
# Average loss at step 16000: 3.430173
# Average loss at step 18000: 3.573787
# Average loss at step 20000: 3.536045
# Nearest to at: in, during, after, on, from, austronesian, outrun, depeche,
# Nearest to been: be, turnpike, never, was, burgess, jati, actually, drusus,
# Nearest to and: or, for, but, unequivocal, gutnish, aerospace, pharmacy, motorways,
# Nearest to d: polymyositis, gerry, heritable, mattingly, somber, disparities, kokhba, machen,
# Nearest to also: often, who, which, still, now, never, must, waive,
# Nearest to who: he, also, harpist, never, they, often, which, woolly,
# Nearest to no: a, mazes, it, modernized, bj, tags, recreating, still,
# Nearest to is: was, are, has, dahalo, be, when, ketamine, palmas,
# Nearest to a: the, this, no, any, moivre, another, induction, fountains,
# Nearest to american: lanthanum, french, papa, fellowships, qualcomm, pebble, rawlings, ami,
# Nearest to may: can, would, will, could, should, must, might, saltire,
# Nearest to have: had, has, be, were, are, synagogues, gladio, stjepan,
# Nearest to world: dorothea, tamer, devo, realaudio, kidnap, u, country, coerce,
# Nearest to not: still, assignments, arose, usually, rough, resembles, overhaul, that,
# Nearest to has: had, have, was, is, idol, lash, after, hyperlinks,
# Nearest to years: days, notes, cheek, staging, organiser, lansing, goldstein, novelist,
# Average loss at step 22000: 3.513369
# Average loss at step 24000: 3.522030
# Average loss at step 26000: 3.529648
# Average loss at step 28000: 3.478010
# Average loss at step 30000: 3.458334
# Nearest to at: in, after, during, on, desecration, depeche, militants, outrun,
# Nearest to been: be, become, turnpike, jati, never, was, burgess, recently,
# Nearest to and: or, in, but, of, soldiery, from, however, which,
# Nearest to d: heritable, gerry, polymyositis, disparities, mattingly, somber, kokhba, r,
# Nearest to also: which, still, often, now, who, there, junit, never,
# Nearest to who: he, never, also, they, she, which, often, harpist,
# Nearest to no: mazes, there, wiping, still, morality, instants, bassists, now,
# Nearest to is: was, are, has, became, had, although, unforeseen, kes,
# Nearest to a: the, airfield, complains, ange, neonatal, macos, factorials, hamilcar,
# Nearest to american: french, papa, lanthanum, ori, african, nihon, pebble, cossiga,
# Nearest to may: can, will, would, could, should, must, might, deficient,
# Nearest to have: had, has, were, are, be, breed, provide, voiced,
# Nearest to world: u, devo, tamer, diodorus, coerce, country, book, gulf,
# Nearest to not: still, usually, it, assignments, berman, never, now, saya,
# Nearest to has: had, have, is, was, deviated, sexagesimal, roadway, idol,
# Nearest to years: days, year, notes, staging, cheek, kyiv, theropod, incensed,
# Average loss at step 32000: 3.180110
# Average loss at step 34000: 3.360170
# Average loss at step 36000: 3.438679
# Average loss at step 38000: 3.311491
# Average loss at step 40000: 3.408302
# Nearest to at: in, after, during, on, within, for, near, thymus,
# Nearest to been: be, become, were, was, turnpike, recently, burgess, drusus,
# Nearest to and: but, or, in, for, she, however, who, taraki,
# Nearest to d: b, heritable, saloons, empties, ili, sadi, edd, polymyositis,
# Nearest to also: still, often, which, who, never, now, actually, that,
# Nearest to who: he, also, she, never, which, they, often, harpist,
# Nearest to no: still, there, a, wiping, mazes, now, patriarchs, brim,
# Nearest to is: was, has, are, be, makes, became, unqualified, does,
# Nearest to a: the, airfield, ange, macos, his, genosha, any, no,
# Nearest to american: english, french, british, showdown, german, bogus, moreno, nihon,
# Nearest to may: can, will, could, would, should, must, might, march,
# Nearest to have: had, has, be, were, are, provide, include, having,
# Nearest to world: u, tamer, diodorus, devo, slant, book, gulf, country,
# Nearest to not: still, only, never, to, saya, you, usually, generally,
# Nearest to has: had, have, is, was, having, byzantine, simcity, pollutant,
# Nearest to years: days, year, months, versions, notes, cheek, staging, organiser,
# Average loss at step 42000: 3.491279
# Average loss at step 44000: 3.436154
# Average loss at step 46000: 3.347572
# Average loss at step 48000: 3.311264
# Average loss at step 50000: 3.425814
# Nearest to at: during, in, near, after, on, loses, candidiasis, outrun,
# Nearest to been: become, be, recently, was, had, traditionally, begun, turnpike,
# Nearest to and: or, but, were, who, soldiery, for, see, chanced,
# Nearest to d: b, polymyositis, sadi, heritable, saloons, empties, langerhans, unintelligent,
# Nearest to also: often, still, now, which, never, actually, junit, who,
# Nearest to who: he, she, never, they, also, slum, lip, often,
# Nearest to no: bassists, confucian, wiping, any, scrolls, patriarchs, annunciation, lure,
# Nearest to is: was, are, has, became, be, were, does, although,
# Nearest to a: the, any, another, ange, tb, cyberpunk, ayub, connected,
# Nearest to american: british, english, french, german, montagu, irish, ukrainian, soddy,
# Nearest to may: can, would, will, could, should, might, must, cannot,
# Nearest to have: had, has, include, were, are, be, provide, having,
# Nearest to world: u, country, tamer, diodorus, gulf, derailleur, brain, precede,
# Nearest to not: usually, still, almost, only, fringes, never, anachronistic, probably,
# Nearest to has: had, is, have, was, byzantine, traversal, deviated, simcity,
# Nearest to years: days, year, months, versions, times, cheek, staging, weeks,
# Average loss at step 52000: 3.453721
# Average loss at step 54000: 3.453895
# Average loss at step 56000: 3.389250
# Average loss at step 58000: 3.357848
# Average loss at step 60000: 3.396145
# Nearest to at: during, after, in, godard, militants, near, visitor, from,
# Nearest to been: become, be, begun, recently, traditionally, already, were, previously,
# Nearest to and: or, but, including, for, s, in, on, against,
# Nearest to d: b, l, polymyositis, c, saloons, adheres, g, p,
# Nearest to also: still, now, often, actually, which, never, usually, junit,
# Nearest to who: she, which, he, often, they, never, that, also,
# Nearest to no: any, wiping, little, bevin, intrinsically, bassists, malthus, scrolls,
# Nearest to is: was, has, are, became, becomes, be, kes, exists,
# Nearest to a: the, airfield, any, ange, hamilcar, cyberpunk, complains, genosha,
# Nearest to american: english, french, british, german, wicked, african, swiss, austrian,
# Nearest to may: can, will, could, would, should, must, might, cannot,
# Nearest to have: had, has, include, be, were, are, provide, refer,
# Nearest to world: country, tamer, derailleur, u, presence, devo, book, civil,
# Nearest to not: still, usually, you, probably, fringes, never, often, it,
# Nearest to has: had, have, is, was, since, simcity, traversal, roadway,
# Nearest to years: days, year, months, versions, times, hours, decades, weeks,
# Average loss at step 62000: 3.335843
# Average loss at step 64000: 3.364761
# Average loss at step 66000: 3.343462
# Average loss at step 68000: 3.309769
# Average loss at step 70000: 3.260328
# Nearest to at: during, near, in, after, on, recreation, serbian, militants,
# Nearest to been: become, be, were, begun, recently, previously, had, already,
# Nearest to and: but, or, who, cfa, however, while, in, although,
# Nearest to d: b, justifies, unintelligent, spousal, jen, empties, sadi, gonzalez,
# Nearest to also: often, still, now, never, actually, who, usually, sometimes,
# Nearest to who: he, often, she, which, never, still, they, also,
# Nearest to no: any, bevin, wiping, little, confucian, bassists, intrinsically, always,
# Nearest to is: was, has, are, phallic, be, being, macao, were,
# Nearest to a: another, ange, any, every, airfield, paged, the, connected,
# Nearest to american: english, british, french, canadian, german, ukrainian, australian, irish,
# Nearest to may: can, should, could, would, must, will, might, cannot,
# Nearest to have: had, has, be, include, were, are, having, provide,
# Nearest to world: u, derailleur, country, diodorus, tamer, interred, erotic, antiques,
# Nearest to not: still, usually, now, never, easily, nowhere, therefore, convergent,
# Nearest to has: had, have, is, was, simcity, since, having, ruiz,
# Nearest to years: days, months, year, versions, hours, weeks, times, decades,
# Average loss at step 72000: 3.287037
# Average loss at step 74000: 3.352295
# Average loss at step 76000: 3.337655
# Average loss at step 78000: 3.327915
# Average loss at step 80000: 3.339517
# Nearest to at: during, in, near, after, within, embalmed, militants, under,
# Nearest to been: become, be, recently, already, previously, were, begun, was,
# Nearest to and: or, including, but, however, tech, pflp, toxic, batch,
# Nearest to d: b, biochemist, empties, saloons, basileus, justifies, january, kaifu,
# Nearest to also: often, still, never, now, actually, sometimes, who, usually,
# Nearest to who: she, which, never, often, he, actually, also, still,
# Nearest to no: any, wiping, little, edmonds, morality, a, patriarchs, confucian,
# Nearest to is: was, has, are, does, phallic, be, if, being,
# Nearest to a: any, another, the, gaunt, ange, cyberpunk, every, no,
# Nearest to american: british, french, canadian, japanese, irish, english, ukrainian, australian,
# Nearest to may: can, should, could, must, would, will, might, cannot,
# Nearest to have: had, has, include, are, were, be, having, refer,
# Nearest to world: country, derailleur, gulf, antiques, u, tamer, civil, foraging,
# Nearest to not: still, never, you, nearly, almost, noticing, fringes, easily,
# Nearest to has: had, have, is, was, since, simcity, having, includes,
# Nearest to years: days, months, year, times, hours, weeks, versions, decades,
# Average loss at step 82000: 3.331257
# Average loss at step 84000: 3.388740
# Average loss at step 86000: 3.356610
# Average loss at step 88000: 3.362658
# Average loss at step 90000: 3.313492
# Nearest to at: during, on, near, after, before, within, inventing, destination,
# Nearest to been: become, be, was, recently, already, previously, were, begun,
# Nearest to and: or, in, but, which, discreet, venetia, including, with,
# Nearest to d: b, biochemist, justifies, adheres, l, saloons, subgroups, heritable,
# Nearest to also: still, now, often, which, never, actually, usually, sometimes,
# Nearest to who: which, she, he, still, often, never, actually, now,
# Nearest to no: any, wiping, little, morality, bassists, dikes, confucian, patriarchs,
# Nearest to is: was, has, are, became, while, becomes, although, were,
# Nearest to a: ange, another, hamilcar, roskilde, hiring, cyberpunk, tagline, eff,
# Nearest to american: african, australian, british, traditional, irish, canadian, clausewitz, english,
# Nearest to may: can, should, must, would, will, could, might, cannot,
# Nearest to have: had, has, include, were, are, be, refer, tend,
# Nearest to world: country, gulf, derailleur, u, sneak, tamer, foraging, ceti,
# Nearest to not: still, never, now, always, usually, generally, almost, nowhere,
# Nearest to has: had, have, is, was, since, docking, includes, slaying,
# Nearest to years: days, months, times, year, decades, weeks, hours, versions,
# Average loss at step 92000: 3.193860
# Average loss at step 94000: 3.325000
# Average loss at step 96000: 3.342463
# Average loss at step 98000: 3.347734
# Average loss at step 100000: 3.356394
# Nearest to at: in, during, on, near, albans, without, militants, multipliers,
# Nearest to been: become, be, being, already, recently, previously, heckler, begun,
# Nearest to and: or, but, while, malleable, including, cormac, archaelogical, kx,
# Nearest to d: b, r, f, adheres, p, justifies, heritable, davidson,
# Nearest to also: still, now, often, actually, never, which, usually, sometimes,
# Nearest to who: which, never, actually, often, they, she, now, still,
# Nearest to no: any, wiping, little, morality, edmond, bassists, intrinsically, only,
# Nearest to is: was, has, are, becomes, phallic, became, remains, miraculous,
# Nearest to a: another, airfield, any, the, punctuated, cyberpunk, every, ange,
# Nearest to american: australian, african, european, french, british, irish, japanese, clausewitz,
# Nearest to may: can, should, must, could, would, will, might, cannot,
# Nearest to have: had, has, include, were, are, be, vindicated, refer,
# Nearest to world: derailleur, largest, tamer, ceti, foraging, jazeera, burgess, antiques,
# Nearest to not: usually, still, now, never, convergent, almost, nowhere, generally,
# Nearest to has: had, have, is, was, since, having, slaying, traversal,
# Nearest to years: days, months, decades, times, year, weeks, hours, centuries,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points', ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
