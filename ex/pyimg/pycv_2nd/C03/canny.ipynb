# %%
# %load canny.py
import cv2
import numpy as np
from matplotlib import pyplot as plot
# %matplotlib inline

img = cv2.imread("../images/statue_small.jpg", 0)
plot.imshow(cv2.Canny(img, 200, 300))
